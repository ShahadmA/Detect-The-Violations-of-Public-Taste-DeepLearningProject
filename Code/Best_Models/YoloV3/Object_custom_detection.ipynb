# %%
from google.colab import drive
drive.mount('/content/gdrive')
# !ln -s /content/gdrive/My\ Drive/ /mydrive
# !ls /mydrive
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# ln: failed to create symbolic link '/mydrive/My Drive': File exists
#  7F2D4DBE-4B34-4CC3-ADF4-BCFE691EB47F.jpeg
# ' Appendix C Reports of organization'
# 'Colab Notebooks'
# 'DD9A1A06-5CD4-4C42-A73B-348E6AC2DB73 - Ghaida Alaqeel.jpeg'
#  DD9A1A06-5CD4-4C42-A73B-348E6AC2DB73.jpeg
#  GhaidaAlaqeel_CV.pdf
# 'My Drive'
#  test_yolo
#  yolo_custom_model_Training
#  yolov3
#  yolov4
# 'جدول بيانات بدون عنوان (1).gsheet'
# 'جدول بيانات بدون عنوان.gsheet'
# 'نموذج بدون عنوان.gform'

# %%
# !ls '/mydrive/yolo_custom_model_Training'
# Out:
# backup	custom_data  custom_data.zip  custom_weight  darknet

# %%
# !unzip '/mydrive/yolo_custom_model_Training/custom_data.zip' -d '/mydrive/yolo_custom_model_Training/'
# Out:
# Archive:  /mydrive/yolo_custom_model_Training/custom_data.zip
# replace /mydrive/yolo_custom_model_Training/custom_data/000-0.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: /mydrive/yolo_custom_model_Training/custom_data/000-0.jpg
# replace /mydrive/yolo_custom_model_Training/custom_data/000-0.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
#   inflating: /mydrive/yolo_custom_model_Training/custom_data/000-0.txt
#   inflating: /mydrive/yolo_custom_model_Training/custom_data/0000003.gif
#   inflating: /mydrive/yolo_custom_model_Training/custom_data/0000003.txt
#   inflating: /mydrive/yolo_custom_model_Training/custom_data/0000004.jpg
#   inflating: /mydrive/yolo_custom_model_Training/custom_data/0000004.txt
#   inflating: /mydrive/yolo_custom_model_Training/custom_data/000001.jpg
#   inflating: /mydrive/yolo_custom_model_Training/custom_data/000001.txt
#   inflating: /mydrive/yolo_custom_model_Training/custom_data/0000019.jpg
# ...

# %%
# !git clone 'https://github.com/AlexeyAB/darknet' '/mydrive/yolo_custom_model_Training/darknet'
# Out:
# fatal: destination path '/mydrive/yolo_custom_model_Training/darknet' already exists and is not an empty directory.

# %%
# %cd /mydrive/yolo_custom_model_Training/darknet
# Out:
# /content/gdrive/My Drive/yolo_custom_model_Training/darknet

# %%
# !ls
# Out:
# 3rdparty	DarknetConfig.cmake.in	json_mjpeg_streams.sh  scripts
# backup		darknet_images.py	LICENSE		       src
# build		darknet.py		Makefile	       vcpkg.json
# build.ps1	darknet_video.py	net_cam_v3.sh	       video_yolov3.sh
# cfg		data			net_cam_v4.sh	       video_yolov4.sh
# cmake		image_yolov3.sh		obj
# CMakeLists.txt	image_yolov4.sh		README.md
# darknet		include			results

# %%
# !make
# Out:
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:946:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
#                        ^~~
# ./src/image_opencv.cpp: In function ‘void draw_train_loss(char*, void**, int, float, float, int, int, float, int, char*, float, int, int, double)’:
# ./src/image_opencv.cpp:1147:13: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
#              if (iteration_old == 0)
#              ^~
# ...

# %%
# !darknet/darknet
# Out:
# usage: darknet/darknet <function>

# %%
# %cd /mydrive/yolo_custom_model_Training
# Out:
# /content/gdrive/My Drive/yolo_custom_model_Training

# %%
# !python custom_data/creating-files-data-and-name.py

# %%
# !python custom_data/creating-train-and-test-txt-files.py

# %%
# !darknet/darknet detector train custom_data/labelled_data.data darknet/cfg/yolov3_custom.cfg custom_weight/darknet53.conv.74 -dont_show
# Out:
# Streaming output truncated to the last 5000 lines.
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 0.000001, iou_loss = 0.000000, total_loss = 0.000001
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000000, iou_loss = 0.000000, total_loss = 0.000000
#  total_bbox = 49116, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.833791), count: 2, class_loss = 0.283170, iou_loss = 0.253787, total_loss = 0.536958
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 0.000012, iou_loss = 0.000000, total_loss = 0.000012
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000002, iou_loss = 0.000000, total_loss = 0.000002
# ...
